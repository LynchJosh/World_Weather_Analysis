# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(city)
# Out:
# 10

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=84379d9d23cfa63dbfaf41107b99010a

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_dscript})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | bor
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | harbour breton
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | evensk
# Processing Record 13 of Set 1 | canon city
# Processing Record 14 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | araouane
# Processing Record 17 of Set 1 | nanchang
# Processing Record 18 of Set 1 | mayumba
# Processing Record 19 of Set 1 | gravelbourg
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | impfondo
# Processing Record 28 of Set 1 | lang son
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | lere
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | safranbolu
# Processing Record 33 of Set 1 | galle
# Processing Record 34 of Set 1 | vung tau
# Processing Record 35 of Set 1 | pierre
# Processing Record 36 of Set 1 | coolum beach
# Processing Record 37 of Set 1 | teya
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | buenos aires
# Processing Record 40 of Set 1 | rawson
# Processing Record 41 of Set 1 | lahij
# Processing Record 42 of Set 1 | college
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | mao
# Processing Record 47 of Set 1 | takoradi
# Processing Record 48 of Set 1 | lufilufi
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | itoman
# Processing Record 2 of Set 2 | road town
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | rehoboth
# Processing Record 8 of Set 2 | yalta
# Processing Record 9 of Set 2 | awbari
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | corn island
# Processing Record 12 of Set 2 | zhezkazgan
# Processing Record 13 of Set 2 | tuatapere
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | comodoro rivadavia
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | ust-kuyga
# Processing Record 20 of Set 2 | biryusinsk
# Processing Record 21 of Set 2 | conakry
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | energetik
# Processing Record 25 of Set 2 | hudson bay
# Processing Record 26 of Set 2 | korla
# Processing Record 27 of Set 2 | sumbe
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | mehamn
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | ostrovnoy
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | guerrero negro
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | karlstad
# Processing Record 37 of Set 2 | smithers
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | arara
# Processing Record 40 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 2 | kavali
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | priiskovyy
# Processing Record 46 of Set 2 | krasnorechenskiy
# Processing Record 47 of Set 2 | ambulu
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | camapua
# Processing Record 50 of Set 2 | mirnyy
# Processing Record 1 of Set 3 | weyburn
# Processing Record 2 of Set 3 | aswan
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | udachnyy
# Processing Record 5 of Set 3 | necochea
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | manaure
# Processing Record 8 of Set 3 | northam
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | pogar
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | lapy
# Processing Record 15 of Set 3 | lata
# Processing Record 16 of Set 3 | namatanai
# Processing Record 17 of Set 3 | hong gai
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | palana
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | jiazi
# Processing Record 26 of Set 3 | chopinzinho
# Processing Record 27 of Set 3 | ucluelet
# Processing Record 28 of Set 3 | emba
# Processing Record 29 of Set 3 | trinidad
# Processing Record 30 of Set 3 | buala
# Processing Record 31 of Set 3 | bogande
# Processing Record 32 of Set 3 | ararangua
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | kuito
# Processing Record 35 of Set 3 | asmar
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | volchanets
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | te anau
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | payo
# Processing Record 43 of Set 3 | una
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | nikel
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | pundaguitan
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | marzuq
# Processing Record 1 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 4 | vaini
# Processing Record 3 of Set 4 | chapais
# Processing Record 4 of Set 4 | mbaiki
# Processing Record 5 of Set 4 | presidencia roque saenz pena
# Processing Record 6 of Set 4 | geraldton
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | aloleng
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | imbituba
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | henties bay
# Processing Record 13 of Set 4 | fallon
# Processing Record 14 of Set 4 | verkhnyaya maksakovka
# Processing Record 15 of Set 4 | mirabad
# Processing Record 16 of Set 4 | eureka
# Processing Record 17 of Set 4 | tiznit
# Processing Record 18 of Set 4 | pacific grove
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | chaah
# Processing Record 22 of Set 4 | gushikawa
# Processing Record 23 of Set 4 | klaksvik
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | hermanus
# Processing Record 26 of Set 4 | pozo colorado
# Processing Record 27 of Set 4 | westport
# Processing Record 28 of Set 4 | berbera
# Processing Record 29 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | davila
# Processing Record 33 of Set 4 | killybegs
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | tomatlan
# Processing Record 37 of Set 4 | vieques
# Processing Record 38 of Set 4 | abu samrah
# Processing Record 39 of Set 4 | aksu
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | taoudenni
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | qaanaaq
# Processing Record 46 of Set 4 | kualakapuas
# Processing Record 47 of Set 4 | chlorakas
# Processing Record 48 of Set 4 | giovinazzo
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | tungor
# Processing Record 1 of Set 5 | rio gallegos
# Processing Record 2 of Set 5 | morondava
# Processing Record 3 of Set 5 | san policarpo
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | devonport
# Processing Record 7 of Set 5 | tecate
# Processing Record 8 of Set 5 | riyadh
# Processing Record 9 of Set 5 | asau
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | reporoa
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | sept-iles
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | lewistown
# Processing Record 16 of Set 5 | manaus
# Processing Record 17 of Set 5 | ponta do sol
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | veraval
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | chisec
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | soto la marina
# Processing Record 24 of Set 5 | altayskoye
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | ahuimanu
# Processing Record 27 of Set 5 | ligayan
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 5 | acapulco
# Processing Record 30 of Set 5 | hualmay
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | tecoanapa
# Processing Record 33 of Set 5 | greenwood
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | panaba
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | makakilo city
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | zhanaozen
# Processing Record 40 of Set 5 | kodiak
# Processing Record 41 of Set 5 | visby
# Processing Record 42 of Set 5 | omsukchan
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 5 | stratford
# Processing Record 46 of Set 5 | ternate
# Processing Record 47 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | barrow
# Processing Record 50 of Set 5 | la tuque
# Processing Record 1 of Set 6 | shelburne
# Processing Record 2 of Set 6 | clyde river
# Processing Record 3 of Set 6 | ngunguru
# Processing Record 4 of Set 6 | kenai
# Processing Record 5 of Set 6 | seminole
# Processing Record 6 of Set 6 | kaduy
# Processing Record 7 of Set 6 | grand gaube
# Processing Record 8 of Set 6 | coihaique
# Processing Record 9 of Set 6 | progreso
# Processing Record 10 of Set 6 | salme
# Processing Record 11 of Set 6 | sozimskiy
# Processing Record 12 of Set 6 | milas
# Processing Record 13 of Set 6 | jackson
# Processing Record 14 of Set 6 | bahia honda
# Processing Record 15 of Set 6 | maksatikha
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | beyneu
# Processing Record 18 of Set 6 | yangambi
# Processing Record 19 of Set 6 | tonj
# Processing Record 20 of Set 6 | conde
# Processing Record 21 of Set 6 | samarai
# Processing Record 22 of Set 6 | kinablangan
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | slave lake
# Processing Record 25 of Set 6 | antofagasta
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | port elizabeth
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 6 | makat
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | oktyabrskiy
# Processing Record 33 of Set 6 | moussoro
# Processing Record 34 of Set 6 | ulaangom
# Processing Record 35 of Set 6 | terenos
# Processing Record 36 of Set 6 | tabas
# Processing Record 37 of Set 6 | banda aceh
# Processing Record 38 of Set 6 | iralaya
# Processing Record 39 of Set 6 | camacha
# Processing Record 40 of Set 6 | minab
# Processing Record 41 of Set 6 | russell
# Processing Record 42 of Set 6 | hailakandi
# Processing Record 43 of Set 6 | mnogovershinnyy
# Processing Record 44 of Set 6 | puerto lempira
# Processing Record 45 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 6 | san quintin
# Processing Record 47 of Set 6 | carutapera
# Processing Record 48 of Set 6 | derzhavinsk
# Processing Record 49 of Set 6 | sohag
# Processing Record 50 of Set 6 | bilibino
# Processing Record 1 of Set 7 | shimoda
# Processing Record 2 of Set 7 | hopkins
# Processing Record 3 of Set 7 | rajakhera
# Processing Record 4 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | jiangyou
# Processing Record 7 of Set 7 | urucara
# Processing Record 8 of Set 7 | dalbandin
# Processing Record 9 of Set 7 | jumla
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | demak
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | itigi
# Processing Record 14 of Set 7 | margate
# Processing Record 15 of Set 7 | verkhoyansk
# Processing Record 16 of Set 7 | todos santos
# Processing Record 17 of Set 7 | grindavik
# Processing Record 18 of Set 7 | dunedin
# Processing Record 19 of Set 7 | batagay-alyta
# Processing Record 20 of Set 7 | hailey
# Processing Record 21 of Set 7 | tiarei
# Processing Record 22 of Set 7 | lincoln
# Processing Record 23 of Set 7 | petrolandia
# City not found. Skipping...
# Processing Record 24 of Set 7 | bandarbeyla
# Processing Record 25 of Set 7 | alofi
# Processing Record 26 of Set 7 | vostok
# Processing Record 27 of Set 7 | bud
# Processing Record 28 of Set 7 | athabasca
# Processing Record 29 of Set 7 | inuvik
# Processing Record 30 of Set 7 | vlore
# Processing Record 31 of Set 7 | kotelnich
# Processing Record 32 of Set 7 | ust-maya
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 35 of Set 7 | provideniya
# Processing Record 36 of Set 7 | ponta delgada
# Processing Record 37 of Set 7 | fethiye
# Processing Record 38 of Set 7 | padang
# Processing Record 39 of Set 7 | mhlume
# Processing Record 40 of Set 7 | chara
# Processing Record 41 of Set 7 | baiyin
# Processing Record 42 of Set 7 | tasiilaq
# Processing Record 43 of Set 7 | prince rupert
# Processing Record 44 of Set 7 | amga
# Processing Record 45 of Set 7 | portland
# Processing Record 46 of Set 7 | lavrentiya
# Processing Record 47 of Set 7 | homer
# Processing Record 48 of Set 7 | alamos
# Processing Record 49 of Set 7 | avera
# Processing Record 50 of Set 7 | tahta
# Processing Record 1 of Set 8 | soe
# Processing Record 2 of Set 8 | madimba
# Processing Record 3 of Set 8 | sylvan lake
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | cidreira
# Processing Record 6 of Set 8 | canyon
# Processing Record 7 of Set 8 | rabo de peixe
# Processing Record 8 of Set 8 | tazovskiy
# Processing Record 9 of Set 8 | havoysund
# Processing Record 10 of Set 8 | bilma
# Processing Record 11 of Set 8 | luwuk
# Processing Record 12 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 13 of Set 8 | port blair
# Processing Record 14 of Set 8 | ustye
# Processing Record 15 of Set 8 | victoria
# Processing Record 16 of Set 8 | birjand
# Processing Record 17 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 8 | hailar
# Processing Record 19 of Set 8 | chake chake
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | ugoofaaru
# Processing Record 22 of Set 8 | lukoyanov
# Processing Record 23 of Set 8 | jijiga
# Processing Record 24 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 25 of Set 8 | bethel
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | hargeysa
# Processing Record 28 of Set 8 | sorland
# Processing Record 29 of Set 8 | pitimbu
# Processing Record 30 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | duma
# Processing Record 33 of Set 8 | aksarka
# Processing Record 34 of Set 8 | kangaatsiaq
# Processing Record 35 of Set 8 | hami
# Processing Record 36 of Set 8 | port lavaca
# Processing Record 37 of Set 8 | kirakira
# Processing Record 38 of Set 8 | kungurtug
# Processing Record 39 of Set 8 | marienburg
# Processing Record 40 of Set 8 | tsiroanomandidy
# Processing Record 41 of Set 8 | airai
# Processing Record 42 of Set 8 | lasa
# Processing Record 43 of Set 8 | quatre cocos
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | ouallam
# Processing Record 46 of Set 8 | abomsa
# Processing Record 47 of Set 8 | biak
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | wajima
# Processing Record 50 of Set 8 | zhigansk
# Processing Record 1 of Set 9 | sur
# Processing Record 2 of Set 9 | dong hoi
# Processing Record 3 of Set 9 | saiha
# Processing Record 4 of Set 9 | ketou
# Processing Record 5 of Set 9 | mkushi
# Processing Record 6 of Set 9 | usinsk
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | warkworth
# Processing Record 9 of Set 9 | koumac
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | chany
# Processing Record 13 of Set 9 | ambovombe
# Processing Record 14 of Set 9 | leuna
# Processing Record 15 of Set 9 | yakeshi
# Processing Record 16 of Set 9 | turmalina
# Processing Record 17 of Set 9 | jiangdu
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | coquimbo
# Processing Record 20 of Set 9 | hasaki
# Processing Record 21 of Set 9 | carndonagh
# Processing Record 22 of Set 9 | miracema do tocantins
# Processing Record 23 of Set 9 | tura
# Processing Record 24 of Set 9 | gboko
# Processing Record 25 of Set 9 | neiafu
# Processing Record 26 of Set 9 | sawang daen din
# Processing Record 27 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 9 | rio verde de mato grosso
# Processing Record 30 of Set 9 | charyshskoye
# Processing Record 31 of Set 9 | malinyi
# Processing Record 32 of Set 9 | saint anthony
# Processing Record 33 of Set 9 | karratha
# Processing Record 34 of Set 9 | kalianget
# Processing Record 35 of Set 9 | cordele
# Processing Record 36 of Set 9 | opuwo
# Processing Record 37 of Set 9 | pochutla
# Processing Record 38 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 9 | houma
# Processing Record 40 of Set 9 | eslov
# Processing Record 41 of Set 9 | matay
# Processing Record 42 of Set 9 | saint-joseph
# Processing Record 43 of Set 9 | thayetmyo
# Processing Record 44 of Set 9 | miramar
# Processing Record 45 of Set 9 | calvinia
# Processing Record 46 of Set 9 | mantenopolis
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | stephenville
# Processing Record 49 of Set 9 | holme
# Processing Record 50 of Set 9 | saint-die
# City not found. Skipping...
# Processing Record 1 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 10 | gilbues
# Processing Record 3 of Set 10 | sola
# Processing Record 4 of Set 10 | mineros
# Processing Record 5 of Set 10 | chulym
# Processing Record 6 of Set 10 | matipo
# Processing Record 7 of Set 10 | sobolevo
# Processing Record 8 of Set 10 | manggar
# Processing Record 9 of Set 10 | surt
# Processing Record 10 of Set 10 | matagami
# Processing Record 11 of Set 10 | izhma
# Processing Record 12 of Set 10 | guiyang
# Processing Record 13 of Set 10 | mae sai
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | tambopata
# Processing Record 16 of Set 10 | byron bay
# Processing Record 17 of Set 10 | vigrestad
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | nebolchi
# Processing Record 20 of Set 10 | grants
# Processing Record 21 of Set 10 | novoorsk
# Processing Record 22 of Set 10 | basco
# Processing Record 23 of Set 10 | bubaque
# Processing Record 24 of Set 10 | antalaha
# Processing Record 25 of Set 10 | kavaratti
# Processing Record 26 of Set 10 | marevo
# Processing Record 27 of Set 10 | jasper
# Processing Record 28 of Set 10 | kaeo
# Processing Record 29 of Set 10 | palkino
# Processing Record 30 of Set 10 | wangqing
# Processing Record 31 of Set 10 | okhotsk
# Processing Record 32 of Set 10 | haines junction
# Processing Record 33 of Set 10 | zaoyang
# Processing Record 34 of Set 10 | kodino
# Processing Record 35 of Set 10 | bulri
# Processing Record 36 of Set 10 | dubbo
# Processing Record 37 of Set 10 | hammerfest
# Processing Record 38 of Set 10 | cedar rapids
# Processing Record 39 of Set 10 | kui buri
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | port pirie
# Processing Record 42 of Set 10 | tabou
# Processing Record 43 of Set 10 | srandakan
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | pisco
# Processing Record 46 of Set 10 | galveston
# Processing Record 47 of Set 10 | yershov
# Processing Record 48 of Set 10 | hervey bay
# Processing Record 49 of Set 10 | ekibastuz
# Processing Record 50 of Set 10 | saratov
# Processing Record 1 of Set 11 | nefteyugansk
# Processing Record 2 of Set 11 | hamilton
# Processing Record 3 of Set 11 | erenhot
# Processing Record 4 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | nalut
# Processing Record 6 of Set 11 | voyvozh
# Processing Record 7 of Set 11 | dodoma
# Processing Record 8 of Set 11 | santa luzia
# Processing Record 9 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | honningsvag
# Processing Record 11 of Set 11 | atasu
# Processing Record 12 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 11 | kultuk
# Processing Record 14 of Set 11 | nemuro
# Processing Record 15 of Set 11 | zeewolde
# Processing Record 16 of Set 11 | mahuva
# Processing Record 17 of Set 11 | port macquarie
# Processing Record 18 of Set 11 | hirado
# Processing Record 19 of Set 11 | broken hill
# Processing Record 20 of Set 11 | union
# Processing Record 21 of Set 11 | tommot
# Processing Record 22 of Set 11 | tarakan
# Processing Record 23 of Set 11 | zharkent
# Processing Record 24 of Set 11 | kununurra
# Processing Record 25 of Set 11 | tshikapa
# Processing Record 26 of Set 11 | la estancia
# Processing Record 27 of Set 11 | ambon
# Processing Record 28 of Set 11 | villa maria
# Processing Record 29 of Set 11 | pangkalanbuun
# Processing Record 30 of Set 11 | harper
# Processing Record 31 of Set 11 | kintampo
# Processing Record 32 of Set 11 | tromso
# Processing Record 33 of Set 11 | contamana
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | vastseliina
# Processing Record 36 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 11 | san jose
# Processing Record 38 of Set 11 | turayf
# Processing Record 39 of Set 11 | shenjiamen
# Processing Record 40 of Set 11 | labuhan
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | quang ngai
# Processing Record 43 of Set 11 | kapustin yar-1
# City not found. Skipping...
# Processing Record 44 of Set 11 | ambilobe
# Processing Record 45 of Set 11 | ladybrand
# Processing Record 46 of Set 11 | horta
# Processing Record 47 of Set 11 | vestmannaeyjar
# Processing Record 48 of Set 11 | paracuru
# Processing Record 49 of Set 11 | nandurbar
# Processing Record 50 of Set 11 | kedougou
# Processing Record 1 of Set 12 | romans-sur-isere
# Processing Record 2 of Set 12 | los llanos de aridane
# Processing Record 3 of Set 12 | pingliang
# Processing Record 4 of Set 12 | kaitangata
# Processing Record 5 of Set 12 | yian
# City not found. Skipping...
# Processing Record 6 of Set 12 | gornoye loo
# Processing Record 7 of Set 12 | sasina
# Processing Record 8 of Set 12 | inhambane
# Processing Record 9 of Set 12 | paita
# Processing Record 10 of Set 12 | nhulunbuy
# Processing Record 11 of Set 12 | mundo nuevo
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | olinda
# Processing Record 14 of Set 12 | svobodnyy
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | sao francisco
# Processing Record 17 of Set 12 | bulaevo
# Processing Record 18 of Set 12 | naze
# Processing Record 19 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 12 | puerto colombia
# Processing Record 21 of Set 12 | faanui
# Processing Record 22 of Set 12 | norden
# Processing Record 23 of Set 12 | mezen
# Processing Record 24 of Set 12 | simao
# Processing Record 25 of Set 12 | balad
# Processing Record 26 of Set 12 | redmond
# Processing Record 27 of Set 12 | gilgit
# Processing Record 28 of Set 12 | maradi
# Processing Record 29 of Set 12 | cam ranh
# Processing Record 30 of Set 12 | cortez
# Processing Record 31 of Set 12 | oranjemund
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | enkhuizen
# Processing Record 34 of Set 12 | okahandja
# Processing Record 35 of Set 12 | shar
# Processing Record 36 of Set 12 | acarau
# Processing Record 37 of Set 12 | senanga
# Processing Record 38 of Set 12 | lyngseidet
# Processing Record 39 of Set 12 | merauke
# Processing Record 40 of Set 12 | graciano sanchez
# Processing Record 41 of Set 12 | eqbaliyeh
# Processing Record 42 of Set 12 | juneau
# Processing Record 43 of Set 12 | lexington
# Processing Record 44 of Set 12 | kutum
# Processing Record 45 of Set 12 | yuancheng
# Processing Record 46 of Set 12 | flin flon
# Processing Record 47 of Set 12 | waw
# Processing Record 48 of Set 12 | asfi
# Processing Record 49 of Set 12 | verkhnevilyuysk
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | el penon
# Processing Record 2 of Set 13 | akyab
# Processing Record 3 of Set 13 | qingyuan
# Processing Record 4 of Set 13 | bosobolo
# Processing Record 5 of Set 13 | talnakh
# Processing Record 6 of Set 13 | fort nelson
# Processing Record 7 of Set 13 | vardo
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | freeport
# Processing Record 10 of Set 13 | port lincoln
# Processing Record 11 of Set 13 | espanola
# Processing Record 12 of Set 13 | yola
# Processing Record 13 of Set 13 | tsurugi
# Processing Record 14 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 13 | luang prabang
# Processing Record 16 of Set 13 | morganton
# Processing Record 17 of Set 13 | tautira
# Processing Record 18 of Set 13 | maymyo
# Processing Record 19 of Set 13 | magistralnyy
# Processing Record 20 of Set 13 | gat
# Processing Record 21 of Set 13 | nova olinda do norte
# Processing Record 22 of Set 13 | manzanillo
# Processing Record 23 of Set 13 | panama city
# Processing Record 24 of Set 13 | morehead
# Processing Record 25 of Set 13 | peleduy
# Processing Record 26 of Set 13 | ust-nera
# Processing Record 27 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 13 | berlevag
# Processing Record 29 of Set 13 | komsomolskiy
# Processing Record 30 of Set 13 | lazaro cardenas
# Processing Record 31 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 13 | xai-xai
# Processing Record 33 of Set 13 | husyatyn
# Processing Record 34 of Set 13 | puerto baquerizo moreno
# Processing Record 35 of Set 13 | luau
# Processing Record 36 of Set 13 | valparaiso
# Processing Record 37 of Set 13 | pontianak
# Processing Record 38 of Set 13 | arkansas city
# Processing Record 39 of Set 13 | barentu
# Processing Record 40 of Set 13 | yala
# Processing Record 41 of Set 13 | jati
# Processing Record 42 of Set 13 | uige
# Processing Record 43 of Set 13 | mandali
# Processing Record 44 of Set 13 | tahoua
# Processing Record 45 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 13 | codajas
# Processing Record 47 of Set 13 | mambajao
# Processing Record 48 of Set 13 | tessalit
# Processing Record 49 of Set 13 | marsa matruh
# Processing Record 50 of Set 13 | kingman
# Processing Record 1 of Set 14 | zhangye
# Processing Record 2 of Set 14 | verkhnyaya sinyachikha
# Processing Record 3 of Set 14 | mackay
# Processing Record 4 of Set 14 | yabelo
# Processing Record 5 of Set 14 | coahuayana
# Processing Record 6 of Set 14 | afsin
# Processing Record 7 of Set 14 | leeston
# Processing Record 8 of Set 14 | skeldon
# Processing Record 9 of Set 14 | rovaniemi
# Processing Record 10 of Set 14 | cap malheureux
# Processing Record 11 of Set 14 | saint-georges
# Processing Record 12 of Set 14 | khash
# Processing Record 13 of Set 14 | am timan
# Processing Record 14 of Set 14 | biograd na moru
# Processing Record 15 of Set 14 | semey
# Processing Record 16 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 14 | balabac
# Processing Record 18 of Set 14 | qingdao
# Processing Record 19 of Set 14 | brae
# Processing Record 20 of Set 14 | la ronge
# Processing Record 21 of Set 14 | najran
# Processing Record 22 of Set 14 | punalur
# Processing Record 23 of Set 14 | nouakchott
# Processing Record 24 of Set 14 | kosa
# Processing Record 25 of Set 14 | orcopampa
# Processing Record 26 of Set 14 | emure
# Processing Record 27 of Set 14 | caravelas
# Processing Record 28 of Set 14 | kieta
# Processing Record 29 of Set 14 | vanavara
# Processing Record 30 of Set 14 | alta floresta
# Processing Record 31 of Set 14 | pangnirtung
# Processing Record 32 of Set 14 | kepno
# Processing Record 33 of Set 14 | lardos
# Processing Record 34 of Set 14 | griffith
# Processing Record 35 of Set 14 | laguna
# Processing Record 36 of Set 14 | palimbang
# Processing Record 37 of Set 14 | katobu
# Processing Record 38 of Set 14 | iringa
# Processing Record 39 of Set 14 | clarksdale
# Processing Record 40 of Set 14 | muros
# Processing Record 41 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 14 | doka
# Processing Record 43 of Set 14 | san juan
# Processing Record 44 of Set 14 | sisimiut
# Processing Record 45 of Set 14 | christchurch
# Processing Record 46 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 14 | porto san giorgio
# Processing Record 48 of Set 14 | fairbanks
# Processing Record 49 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 14 | angoche

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data_df)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head()

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
